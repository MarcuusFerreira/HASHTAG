# %% [markdown]
# # pandas e csv
#
# ## Resumo
#
# Quase sempre quando formos "ler" um arquivo csv, vamos usar o pandas. É prático e bem eficiente.
#
# ## Funcionamento

# %% [raw]
# Forma mais básica: (muitas vezes não usaremos a forma mais básica)
# dataframe = pd.read_csv(arquivo_com_extensao)

# %% [markdown]
# - Vamos ler um arquivo real, com a Base de Dados de Vendas da Empresa "Contoso"

# %%
import pandas as pd

# %%
vendas_df = pd.read_csv('Contoso - Vendas - 2017.csv', sep=';')
produtos_df = pd.read_csv('Contoso - Cadastro Produtos.csv', sep=';')

vendas_df.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# c:\eu\eu\Python\HASHTAG\modulo_21\Pandas 03.ipynb Cell 5 line 2
#       <a href='vscode-notebook-cell:/c%3A/eu/eu/Python/HASHTAG/modulo_21/Pandas%2003.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> vendas_df = pd.read_csv('Contoso - Vendas - 2017.csv', sep=';')
# ----> <a href='vscode-notebook-cell:/c%3A/eu/eu/Python/HASHTAG/modulo_21/Pandas%2003.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> produtos_df = pd.read_csv('Contoso - Cadastro Produtos.csv', sep=';')
#       <a href='vscode-notebook-cell:/c%3A/eu/eu/Python/HASHTAG/modulo_21/Pandas%2003.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> vendas_df.head()
#
# ...

# %%
vendas_df = vendas_df.rename(columns={'Numero da Venda': 'num_venda',
                              'Data da Venda': 'dt_venda',
                              'Data do Envio': 'dt_envio',
                              'ID Canal': 'id_canal',
                              'ID Loja': 'id_loja',
                              'ID Produto': 'id_produto',
                              'ID Promocao': 'id_promocao',
                              'ID Cliente': 'id_cliente',
                              'Quantidade Vendida': 'qtd_vendida',
                              'Quantidade Devolvida': 'qtd_devolvida'})

vendas_df.head()
# Out:
#    num_venda    dt_venda    dt_envio  id_canal  id_loja  id_produto  \
# 0          1  01/01/2017  02/01/2017         1       86         981
# 1          2  01/01/2017  06/01/2017         5      308        1586
# 2          3  01/01/2017  01/01/2017         0      294        1444
# 3          4  01/01/2017  01/01/2017         0      251        1468
# 4          5  01/01/2017  07/01/2017         6       94        1106
#
#    id_promocao  id_cliente  qtd_vendida  qtd_devolvida
# 0            2        6825            9              1
# 1            2       18469            9              1
# 2            5       19730           13              1
# 3            5       29326            6              1
# 4            2       22617            4              1

# %%
vendas_df[['num_venda', 'dt_venda', 'id_produto']]
# Out:
#         num_venda    dt_venda  id_produto
# 0               1  01/01/2017         981
# 1               2  01/01/2017        1586
# 2               3  01/01/2017        1444
# 3               4  01/01/2017        1468
# 4               5  01/01/2017        1106
# ...           ...         ...         ...
# 980637     980638  31/12/2017        2490
# 980638     980639  31/12/2017        2488
# 980639     980640  31/12/2017        2511
# 980640     980641  31/12/2017         436
# 980641     980642  31/12/2017        2510
#
# [980642 rows x 3 columns]

# %%
vendas_df['id_produto'][0]
# Out:
# 981

# %%
lista_clientes = vendas_df['id_cliente'].tolist()
lista_clientes
# Out:
# [6825,
#  18469,
#  19730,
#  29326,
#  22617,
#  7910,
#  11720,
#  26558,
#  32396,
#  31290,
#  30488,
#  18561,
#  25632,
#  30401,
#  36839,
#  27645,
#  7991,
#  35762,
#  24240,
#  13399,
#  27222,
#  9899,
#  13178,
#  23285,
#  27220,
#  23613,
#  27751,
#  30742,
#  10597,
#  18835,
#  14236,
#  10188,
#  32657,
#  12781,
#  24767,
#  11620,
#  10984,
#  35373,
#  24513,
#  32258,
#  30065,
#  5852,
#  13297,
#  30694,
#  6090,
#  19387,
#  33168,
#  26865,
#  2670,
#  17716,
#  9584,
#  4689,
#  17747,
#  20073,
#  14545,
#  12488,
#  22230,
#  17128,
#  29219,
#  28559,
#  24663,
#  13911,
#  12612,
#  26222,
#  26147,
#  16508,
#  27178,
#  9044,
#  34242,
#  33448,
#  30486,
#  2817,
#  13517,
#  8503,
#  32479,
#  19562,
#  9278,
#  15000,
#  11415,
#  13507,
#  18494,
#  18327,
#  5211,
#  15331,
#  14821,
#  26928,
#  27168,
#  30262,
#  12928,
#  20897,
#  15803,
#  11818,
#  11203,
#  12802,
#  20682,
#  8731,
#  22532,
#  36137,
#  26238,
#  5655,
#  15871,
# ...

# %%
df_produtos_qtd = vendas_df[['id_produto', 'qtd_vendida', 'qtd_devolvida']]
df_produtos_qtd
# Out:
#         id_produto  qtd_vendida  qtd_devolvida
# 0              981            9              1
# 1             1586            9              1
# 2             1444           13              1
# 3             1468            6              1
# 4             1106            4              1
# ...            ...          ...            ...
# 980637        2490          120              0
# 980638        2488          120              0
# 980639        2511           80              0
# 980640         436           39              0
# 980641        2510           80              0
#
# [980642 rows x 3 columns]
